# %%
import pandas
dt= pandas.read_csv('csv_data.csv')
dt.fillna(0, inplace= True)

# %%
from matplotlib import pyplot
pyplot.plot(dt['id'],dt['sales'], '.c', markersize= 25)
pyplot.title('product sales')
pyplot.xlabel('Product id')
pyplot.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')
